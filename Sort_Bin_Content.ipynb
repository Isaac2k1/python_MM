# %% [markdown]
# # Sort bin content
# Several bins contain cloured marbles which have to be sorted.
# There is e.g. 14 bins total and two of them are empty.
# The other 12 contain 4 marbles of mixed colours.
# The aim of the game is to sort the marbles, such that each bin has marbles of the same colour, 6 bins with 4 marbles of the same colour.
# Condition is that a marble can be moved to an empty space only, if the bin is empty or the marble underneath has the same colour.
#
# ![image.jpeg](attachment:image.jpeg)

# %% [markdown]
# |colour = abbr.   |colour = abbr.    |colour = abbr.|
# |-----------------|------------------|--------------|
# |yellow = 'ye'    |pink = 'pi'       |orange = 'or' |
# |red = 'rd'       |light green = 'lg'|green = 'gn'  |
# |dark green = 'dg'|light blue = 'lb' |blue = 'bl'   |
# |violet = 'vt'    |grey = 'gr'       |brown = 'br'  |
# |blank or empty place in bin = 'bk'|

# %%
colours = ['ye', 'pi', 'or', 'rd', 'lg', 'gn', 'dg', 'lb', 'bl', 'vt', 'gr', 'br']

# %%
from array import *
arr = [['gn','gr','bl','or'],['or','or','pi','ye'],['ye','or','rd','dg'],
       ['vt','vt','bl','lb'],['ye','gn','br','bl'],['rd','bl','pi','gn'],
       ['lb','br','bl','br'],['gn','pi','gr','lb'],['pi','gn','rd','vt'],
       ['ye','lg','gn','rd'],['gr','gr','br','lg'],['lg','vt','dg','dg'],
       ['bk','bk','bk','bk'],['bk','bk','bk','bk']]

# %%
print(arr)
# Out:
# [['gn', 'gr', 'bl', 'or'], ['or', 'or', 'pi', 'ye'], ['ye', 'or', 'rd', 'dg'], ['vt', 'vt', 'bl', 'lb'], ['ye', 'gn', 'br', 'bl'], ['rd', 'bl', 'pi', 'gn'], ['lb', 'br', 'bl', 'br'], ['gn', 'pi', 'gr', 'lb'], ['pi', 'gn', 'rd', 'vt'], ['ye', 'lg', 'gn', 'rd'], ['gr', 'gr', 'br', 'lg'], ['lg', 'vt', 'dg', 'dg'], ['bk', 'bk', 'bk', 'bk'], ['bk', 'bk', 'bk', 'bk']]

# %%
arr.count('gn')

# %%
def factorial(n):
    if (n<= 1):
        return 1
    else:
        print(n)
        subSolution = factorial(n-1)
        solution = subSolution * n
        return solution
    
print(factorial(6))
# Out:
# 6
# 5
# 4
# 3
# 2
# 720

# %%
for bin in range(14):
    print(bin,arr[bin])
# Out:
# 0 ['gn', 'gr', 'bl', 'or']
# 1 ['or', 'or', 'pi', 'ye']
# 2 ['ye', 'or', 'rd', 'dg']
# 3 ['vt', 'vt', 'bl', 'lb']
# 4 ['ye', 'gn', 'br', 'bl']
# 5 ['rd', 'bl', 'pi', 'gn']
# 6 ['lb', 'br', 'bl', 'br']
# 7 ['gn', 'pi', 'gr', 'lb']
# 8 ['pi', 'gn', 'rd', 'vt']
# 9 ['ye', 'lg', 'gn', 'rd']
# 10 ['gr', 'gr', 'br', 'lg']
# 11 ['lg', 'vt', 'dg', 'dg']
# 12 ['bk', 'bk', 'bk', 'bk']
# 13 ['bk', 'bk', 'bk', 'bk']
